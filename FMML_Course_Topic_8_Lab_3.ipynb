# %% [markdown]
# <a href="https://colab.research.google.com/github/anushayarramsetti/FMMLLAB1/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-30 15:38:31--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   194MB/s    in 0.4s
#
# 2024-03-30 15:38:31 (194 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3828 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 3086 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 54  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 9  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 4440   1710.10348v2  Deep residual networks (ResNets) and their var...  stat
# 3294    1412.6808v2  Modern information processing relies on the ax...  stat
# 19115   1304.1125v1  In this paper a new mathematical procedure is ...    cs
# 12950   1209.2620v1  Automated reasoning about uncertain knowledge ...    cs
# 16097  1609.07053v2  We propose a novel semantic tagging task, sem-...    cs
# ...             ...                                                ...   ...
# 16051  1608.07738v2  In Distributional Semantic Models (DSMs), Vect...    cs
# 30145  1711.07835v1  Discriminative correlation filter (DCF) based ...    cs
# 19481   1107.4035v2  The promise of lifted probabilistic inference ...    cs
# 6281   1610.08838v1  Supervised dimensionality reduction has emerge...  stat
# 8529   1703.07332v3  This paper investigates how far a very deep ne...    cs
#
#                                                    title  year  \
# 4440   Multi-level Residual Networks from Dynamical S...  2017
# 3294   Learning the nonlinear geometry of high-dimens...  2014
# 19115  Evidence Combination and Reasoning and Its App...  2013
# 12950  Probabilities on Sentences in an Expressive Logic  2012
# 16097       Semantic Tagging with Deep Residual Networks  2016
# ...                                                  ...   ...
# 16051  Testing APSyn against Vector Cosine on Similar...  2016
# 30145  Robust Object Tracking Based on Self-adaptive ...  2017
# 19481  Towards Completely Lifted Search-based Probabi...  2011
# 6281   A Category Space Approach to Supervised Dimens...  2016
# 8529   How far are we from solving the 2D & 3D Face A...  2017
#
#                                                 keywords
# 4440   [applications, processing, theoretical, princi...
# 3294   [information, processing, dimensional, dimensi...
# 19115  [mathematical, procedure, presented, combining...
# 12950  [automated, reasoning, uncertain, knowledge, a...
# 16097  [multilingual, character, representations, arc...
# ...                                                  ...
# 16051  [distributional, similarity, shortcomings, lit...
# 30145  [discriminative, correlation, excellent, perfo...
# 19481  [probabilistic, inference, probabilistic, infe...
# 6281   [supervised, dimensionality, reduction, import...
# 8529   [investigates, attaining, saturating, performa...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 4440     [applications, processing, theoretical, princi...
# 3294     [information, processing, dimensional, dimensi...
# 19115    [mathematical, procedure, presented, combining...
# 12950    [automated, reasoning, uncertain, knowledge, a...
# 16097    [multilingual, character, representations, arc...
#                                ...
# 32000    [hypotheses, hierarchical, relationship, intui...
# 25973    [innovations, convolutional, motivated, automa...
# 29473    [recognition, published, recognition, describi...
# 10044    [structural, parametric, structural, treatment...
# 37390    [introduce, qualitative, probabilistic, progra...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8706 words.
# Out of those 4604 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="341d1097-5f17-450e-8a27-77f8c53f6178" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("341d1097-5f17-450e-8a27-77f8c53f6178")) {                    Plotly.newPlot(                        "341d1097-5f17-450e-8a27-77f8c53f6178",                        [{"x":["iterative","designing","estimation","dynamical","applications","theoretical","properties","processing","principles","interpret","benchmarks","experimentally","classification","theoretically","understood","additionally","accelerating","efficiently","dimensional","clustering","demonstrate","describing","underlying","involving","superiority","information","literature","structures","algorithms","generalizes","following","connections","experiments","synthetic","approaches","subspaces","contributions","formalizes","nonlinear","motivates","constrained","geometric","numerical","manifolds","mathematical","different","independent","correlated","performance","generated","reasonably","extensions","intuition","combination","methodology","represented","application","knowledge","essential","hypothesis","combining","dependent","evidences","conflicting","procedure","presented","reasoning","construct","sentences","developed","distribution","conditions","technical","sufficient","structured","inference","languages","characterizations","representing","empirically","completely","universally","necessary","requirements","confirmation","particular","consistent","inductive","extending","approximated","probability","developing","integration","uncertain","automated","satisfying","translate","expressive","autonomous","constructions","probabilities","quantified","satisfactory","difficulty","deductive","unification","outperforms","significantly","intrinsically","dependencies","multilingual","architecture","auxiliary","representations","universal","predicting","character","consisting","objective","approximations","optimality","demonstrations","existence","reinforcement","introduce","stochastic","algorithm","competitive","strategies","considers","equilibrium","adversarial","functions","unlabeled","minimization","measurements","alternating","initialization","regression","iteration","eigenvectors","converges","assumptions","appropriate","complexity","characterization","predictive","unsupervised","supervised","sectional","embeddings","neighborhood","embedding","comparable","performed","prediction","contributes","formation","communicating","convolutional","recognition","subsequently","instruction","scenarios","requiring","efficiency","framework","efficient","programming","instructions","simulation","computationally","portability","illustrates","syntactically","underwater","parameters","deterministic","intuitive","usability","potentially","collaboration","meaningful","robustness","collaborative","parameter","reconfiguration","interaction","artificial","extensive","resulting","similarity","fulfilled","environment","therefore","categories","splitting","identification","represent","subsymbolic"],"y":[84,44,193,17,424,176,212,287,28,19,79,43,487,42,25,60,9,151,196,125,569,33,120,59,41,715,133,138,573,31,79,43,599,136,462,14,50,1,60,8,75,74,74,23,58,754,115,33,860,187,8,45,25,142,66,89,240,353,75,54,94,70,7,10,111,188,128,77,72,182,233,129,41,67,95,211,90,5,76,78,36,4,76,59,2,267,93,17,21,13,170,52,55,25,110,12,25,26,63,7,58,11,17,46,7,7,256,263,7,57,20,216,23,213,33,77,47,46,144,37,23,8,36,117,357,107,794,120,100,29,16,105,221,47,58,56,32,31,109,43,8,24,65,70,242,27,55,127,192,1,61,25,112,104,144,216,10,13,6,368,368,32,6,90,45,158,553,405,120,7,76,103,8,9,7,4,235,36,30,5,42,7,48,96,46,133,2,79,138,173,146,170,4,117,130,75,11,81,118,2],"type":"bar"},{"x":["iterative","designing","estimation","dynamical","appl ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4604,), (4604, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7966666666666666

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Predicting</span> <span style=''>Face</span> <span style='background-color:rgba(0, 255, 0, 0.6391982182628062);'>Recognition</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Performance</span> <span style=''>Using</span> <span style=''>Image</span> <span style=''>Quality</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style=''>proposes</span> <span style=''>a</span> <span style=''>data</span> <span style=''>driven</span> <span style=''>model</span> <span style=''>to</span> <span style=''>predict</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>of</span> <span style=''>a</span> <span style=''>face</span> <span style='background-color:rgba(0, 255, 0, 0.6391982182628062);'>recognition</span> <span style=''>system</span> <span style=''>based</span> <span style=''>on</span> <span style=''>image</span> <span style=''>quality</span> <span style=''>features</span> <span style=''>We</span> <span style=''>model</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>relationship</span> <span style=''>between</span> <span style=''>image</span> <span style=''>quality</span> <span style=''>features</span> <span style=''>(eg</span> <span style=''>pose</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>illumination</span> <span style=''>etc)</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.6391982182628062);'>recognition</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>measures</span> <span style=''>using</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style=''>density</span> <span style=''>function</span> <span style=''>To</span> <span style=''>address</span> <span style=''>the</span> <span style=''>issue</span> <span style=''>of</span> <span style=''>limited</span> <span style=''>nature</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>practical</span> <span style=''>training</span> <span style=''>data</span> <span style=''>inherent</span> <span style=''>in</span> <span style=''>most</span> <span style=''>data</span> <span style=''>driven</span> <span style=''>models</span> <span style=''>we</span> <span style=''>have</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>developed</span> <span style=''>a</span> <span style=''>Bayesian</span> <span style=''>approach</span> <span style=''>to</span> <span style=''>model</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.6391982182628062);'>recognition</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>measures</span> <span style=''>in</span> <span style=''>small</span> <span style=''>regions</span> <span style=''>of</span> <span style=''>the</span> <span style=''>quality</span> <span style=''>space</span> <span style=''>Since</span> <span style=''>the</span> <span style=''>model</span> <span style=''>is</span> <span style=''>based</span> <span style=''>solely</span> <span style=''>on</span> <span style=''>image</span> <span style=''>quality</span> <span style=''>features</span> <span style=''>it</span> <span style=''>can</span> <span style=''>predict</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>even</span> <span style=''>before</span> <span style=''>the</span> <span style=''>actual</span> <span style='background-color:rgba(0, 255, 0, 0.6391982182628062);'>recognition</span> <span style=''>has</span> <span style=''>taken</span> <span style=''>place</span> <span style=''>We</span> <span style=''>evaluate</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>Direct</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Estimation</span> <span style=''>of</span> <span style=''>High</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dimensional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Stationary</span> <span style=''>Vector</span> <span style=''>Autoregressions</span> <br/><br/><span style=''>The</span> <span style=''>vector</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>autoregressive</span> <span style=''>(VAR)</span> <span style=''>model</span> <span style=''>is</span> <span style=''>a</span> <span style=''>powerful</span> <span style=''>tool</span> <span style=''>in</span> <span style=''>modeling</span> <span style=''>complex</span> <span style=''>time</span> <span style=''>series</span> <span style=''>and</span> <span style=''>has</span> <span style=''>been</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>exploited</span> <span style=''>in</span> <span style=''>many</span> <span style=''>fields</span> <span style=''>However</span> <span style=''>fitting</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>VAR</span> <span style=''>model</span> <span style=''>poses</span> <span style=''>some</span> <span style=''>unique</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenges</span> <span style=''>On</span> <span style=''>one</span> <span style=''>hand</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensionality</span> <span style=''>caused</span> <span style=''>by</span> <span style=''>modeling</span> <span style=''>a</span> <span style=''>large</span> <span style=''>number</span> <span style=''>of</span> <span style=''>time</span> <span style=''>series</span> <span style=''>and</span> <span style=''>higher</span> <span style=''>order</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>autoregressive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <span style=''>is</span> <span style=''>usually</span> <span style=''>much</span> <span style=''>higher</span> <span style=''>than</span> <span style=''>the</span> <span style=''>time</span> <span style=''>series</span> <span style=''>length</span> <span style=''>On</span> <span style=''>the</span> <span style=''>other</span> <span style=''>hand</span> <span style=''>the</span> <span style=''>temporal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dependence</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>in</span> <span style=''>the</span> <span style=''>VAR</span> <span style=''>model</span> <span style=''>gives</span> <span style=''>rise</span> <span style=''>to</span> <span style=''>extra</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenges</span> <span style=''>In</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensions</span> <span style=''>one</span> <span style=''>popular</span> <span style=''>approach</span> <span style=''>is</span> <span style=''>to</span> <span style=''>assume</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>transition</span> <span style=''>matrix</span> <span style=''>is</span> <span style=''>sparse</span> <span style=''>and</span> <span style=''>fit</span> <span style=''>the</span> <span style=''>VAR</span> <span style=''>model</span> <span style=''>using</span> <span style=''>the</span> <span style=''>least</span> <span style=''>squares</span> <span style=''>method</span> <span style=''>with</span> <span style=''>a</span> <span style=''>lasso</span> <span style=''>type</span> <span style=''>penalty</span> <span style=''>In</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>manuscript</span> <span s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Consistent</span> <span style=''>Sparse</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Estimation</span> <span style=''>through</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.7142857142857143);'>Bootstrap</span> <br/><br/><span style=''>We</span> <span style=''>consider</span> <span style=''>the</span> <span style=''>least</span> <span style=''>square</span> <span style=''>linear</span> <span style='background-color:rgba(255, 0, 0, 0.5301724137931034);'>regression</span> <span style=''>problem</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regularization</span> <span style=''>by</span> <span style=''>the</span> <span style=''>ell1</span> <span style=''>norm</span> <span style=''>a</span> <span style=''>problem</span> <span style=''>usually</span> <span style=''>referred</span> <span style=''>to</span> <span style=''>as</span> <span style=''>the</span> <span style=''>Lasso</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>first</span> <span style=''>present</span> <span style=''>a</span> <span style=''>detailed</span> <span style='background-color:rgba(255, 0, 0, 0.6346153846153846);'>asymptotic</span> <span style=''>analysis</span> <span style=''>of</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consistency</span> <span style=''>of</span> <span style=''>the</span> <span style=''>Lasso</span> <span style=''>in</span> <span style=''>low</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dimensional</span> <span style=''>settings</span> <span style=''>For</span> <span style=''>various</span> <span style=''>decays</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regularization</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameter</span> <span style=''>we</span> <span style=''>compute</span> <span style='background-color:rgba(255, 0, 0, 0.6346153846153846);'>asymptotic</span> <span style='background-color:rgba(0, 255, 0, 0.6666666666666666);'>equivalents</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style=''>of</span> <span style=''>correct</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>selection</span> <span style=''>For</span> <span style=''>a</span> <span style=''>specific</span> <span style=''>rate</span> <span style=''>decay</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style=''>Lasso</span> <span style=''>selects</span> <span style=''>all</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.41293532338308464);'>variables</span> <span style=''>that</span> <span style=''>should</span> <span style=''>enter</span> <span style=''>the</span> <span style=''>model</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style=''>tending</span> <span style=''>to</span> <span style=''>one</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>exponentially</span> <span style=''>fast</span> <span style=''>while</span> <span style=''>it</span> <span style=''>selects</span> <span style=''>all</span> <span style=''>other</span> <span style='background-color:rgba(255, 0, 0, 0.41293532338308464);'>variables</span> <span style=''>with</span> <span style=''>strictly</span> <span style=''>positive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>this</span> <span style=''>property</span> <span style=''>implies</span> <span style=''>that</span> <span style=''>if</span> <sp ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Sequential</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Principal</span> <span style=''>Curves</span> <span style=''>Analysis</span> <br/><br/><span style=''>This</span> <span style=''>work</span> <span style=''>includes</span> <span style=''>all</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>technical</span> <span style=''>details</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Sequential</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Principal</span> <span style=''>Curves</span> <span style=''>Analysis</span> <span style=''>(SPCA)</span> <span style=''>in</span> <span style=''>a</span> <span style=''>single</span> <span style=''>document</span> <span style=''>SPCA</span> <span style=''>is</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unsupervised</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonlinear</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>invertible</span> <span style=''>feature</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extraction</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>technique</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>identified</span> <span style=''>curvilinear</span> <span style=''>features</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interpreted</span> <span style=''>as</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonlinear</span> <span style=''>sensors</span> <span style=''>the</span> <span style=''>response</span> <span style=''>of</span> <span style=''>each</span> <span style=''>sensor</span> <span style=''>is</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>projection</span> <span style=''>onto</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>corresponding</span> <span style=''>feature</span> <span style=''>Moreover</span> <span style=''>it</span> <span style=''>can</span> <span style=''>be</span> <span style=''>easily</span> <span style=''>tuned</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>criteria</span> <span style=''>eg</span> <span style=''>infomax</span> <span style=''>error</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>minimization</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>decorrelation</span> <span style=''>by</span> <span style=''>choosing</span> <span style=''>the</span> <span style=''>right</span> <span style=''>way</span> <span style=''>to</span> <span style=''>measure</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distances</span> <span style=''>along</span> <span style=''>each</span> <span style=''>curvilinear</span> <span style=''>feature</span> <span style=''>Even</span> <span style=''>though</span> <span style=''>proposed</span> <span style=''>in</span> <span style=''>Laparra</span> <span style=''>et</span> <span style=''>al</span> <span style=''>Neural</span> <span style=''>Comp</span> <span style=''>12</span> <span style=''>and</span> <span style=''>shown</span> <span style=''>to</span> <span style=''>work</span> <span style=''>in</span> <span style=''>multiple</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>modalities</span> <span style=''>in</span> <span style=''>Laparra</span> <span style=''>and</span> <span style=''>Malo</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Frontiers</span> <span style=''>Hum</span> <span style=''>Neuro</span> <span style=''>15</span> <span style=''>the</span> <span sty ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	processing (0.10191761363636363)
# 	segmentation (0.06569602272727272)
# 	challenging (0.09588068181818182)
# 	experimental (0.1338778409090909)
# 	representation (0.13032670454545456)
# 	information (0.25390625)
# 	different (0.2677556818181818)
# 	detection (0.13245738636363635)
# 	convolutional (0.13068181818181818)
# 	recognition (0.13068181818181818)
#
# Some Statistics words are:
# 	variational (0.10584677419354839)
# 	theoretical (0.15675403225806453)
# 	variables (0.1431451612903226)
# 	estimation (0.17036290322580644)
# 	distribution (0.18548387096774194)
# 	stochastic (0.14213709677419356)
# 	algorithm (0.390625)
# 	dimensional (0.1814516129032258)
# 	inference (0.20161290322580644)
# 	regression (0.17893145161290322)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d1393114-10ab-4111-87a0-030e7211fd62" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d1393114-10ab-4111-87a0-030e7211fd62")) {                    Plotly.newPlot(                        "d1393114-10ab-4111-87a0-030e7211fd62",                        [{"x":["iterative","designing","estimation","dynamical","applications","theoretical","properties","processing","principles","interpret","benchmarks","experimentally","classification","theoretically","understood","additionally","accelerating","efficiently","dimensional","clustering","demonstrate","describing","underlying","involving","superiority","information","literature","structures","algorithms","generalizes","following","connections","experiments","synthetic","approaches","subspaces","contributions","formalizes","nonlinear","motivates","constrained","geometric","numerical","manifolds","mathematical","different","independent","correlated","performance","generated","reasonably","extensions","intuition","combination","methodology","represented","application","knowledge","essential","hypothesis","combining","dependent","evidences","conflicting","procedure","presented","reasoning","construct","sentences","developed","distribution","conditions","technical","sufficient","structured","inference","languages","characterizations","representing","empirically","completely","universally","necessary","requirements","confirmation","particular","consistent","inductive","extending","approximated","probability","developing","integration","uncertain","automated","satisfying","translate","expressive","autonomous","constructions","probabilities","quantified","satisfactory","difficulty","deductive","unification","outperforms","significantly","intrinsically","dependencies","multilingual","architecture","auxiliary","representations","universal","predicting","character","consisting","objective","approximations","optimality","demonstrations","existence","reinforcement","introduce","stochastic","algorithm","competitive","strategies","considers","equilibrium","adversarial","functions","unlabeled","minimization","measurements","alternating","initialization","regression","iteration","eigenvectors","converges","assumptions","appropriate","complexity","characterization","predictive","unsupervised","supervised","sectional","embeddings","neighborhood","embedding","comparable","performed","prediction","contributes","formation","communicating","convolutional","recognition","subsequently","instruction","scenarios","requiring","efficiency","framework","efficient","programming","instructions","simulation","computationally","portability","illustrates","syntactically","underwater","parameters","deterministic","intuitive","usability","potentially","collaboration","meaningful","robustness","collaborative","parameter","reconfiguration","interaction","artificial","extensive","resulting","similarity","fulfilled","environment","therefore","categories","splitting","identification","represent","subsymbolic","constraint","interactions","encountered","rademacher","generalized","univariate","nonparametric","regularization","component","learnability","variation","tibshirani","statistical","generalization","explanatory","according","abnormality","membership","identified","identifying","experimental","extracted","diagnosis","screening","mammogram","abnormalities","oncologists","preprocessed","selection","diagnosed","researchers","mammograms","difficult","descriptions","architectures","attention","arbitrary","introducing","demonstrates","annotations","captioning","important","implicitly","predicted","available","imagevideo","providing","spatiotemporal","evaluation","representation","challenging","counterpart","surprisingly","v ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	tibshirani
# 	convolved
# 	coregionalization
# 	dependences
# 	foundational
# 	prognostic
# 	recombines
# 	sentinels
# 	identifiable
# 	spectroradiometer
# 	lancaster
# 	connectome
# 	embarrassingly
# 	poisoning
# 	undermine
# 	detectability
# 	martingale
# 	jackknife
# 	portraits
# 	modulating
# Some words which never appear in Statistics papers:
# 	evidences
# 	confirmation
# 	deductive
# 	instruction
# 	instructions
# 	portability
# 	syntactically
# 	underwater
# 	subsymbolic
# 	mammogram
# 	oncologists
# 	mammograms
# 	imagevideo
# 	illumination
# 	observability
# 	unvisited
# 	prioritized
# 	connectionist
# 	utterance
# 	documentation

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.052130387010133e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7433333333333333
